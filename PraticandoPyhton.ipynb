# %% [markdown]
# <a href="https://colab.research.google.com/github/WeydisonAndrade/Pratica_Python_Para_Dados1_Alura/blob/main/PraticandoPyhton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1) Escreva um programa que peça dois números inteiros e imprima todos os números inteiros entre eles

# %%
# Entrada de dados
num1 = int(input("Digite o primeiro número inteiro: "))
num2 = int(input("Digite o segundo número inteiro: "))

# Processamento de dados
for i in range(num1 + 1, num2):
    print(i)

# %% [markdown]
# 2) Escreva um programa para calcular quantos dias levará para a colônia de uma bactéria A ultrapassar ou igualar a colônia de uma bactéria B, com base nas taxas de crescimento de 3% e 1,5% respectivamente. Considere que a colônia A inicia com 4 elementos e a B com 10.

# %%
# Entrada de dados
bacteriaA = 4
bacteriaB = 10
# Contador de dias
dias = 0
while bacteriaA <= bacteriaB:
    bacteriaA += bacteriaA * 0.03
    bacteriaB += bacteriaB * 0.015
    dias += 1
print(f'A colônia A irá ultrapassar a colônia B em {dias} dias! ')
print(f'Quantidade final de bactérias na colônia A: {bacteriaA:.2f}')
print(f'Quantidade final de bactérias na colônia B: {bacteriaB:.2f}')
# Out:
# A colônia A irá ultrapassar a colônia B em 63 dias!
# Quantidade final de bactérias na colônia A: 25.75
# Quantidade final de bactérias na colônia B: 25.55

# %% [markdown]
# 3) Para tratar uma quantidade de 15 dados de avaliações de pessoas usuárias de um serviço da empresa, precisamos verificar se as notas são válidas. Então, escreva um programa que vai receber a nota de 0 a 5 de todos os dados e verificar se é um valor válido. Caso seja inserido uma nota acima de 5 ou abaixo de 0, repita até que a pessoa usuária insira um valor válido.

# %%
# Entrada de dados
for i in range(15):

    nota = int(input("Digite uma nota de 0 a 5: "))

    # Validação
    while nota < 0 or nota > 5:
        print("Nota inválida!")
        nota = int(input("Digite uma nota de 0 a 5: "))

    print("Nota válida!")

# %% [markdown]
# 4) Desenvolva um programa que leia um conjunto indeterminado de temperaturas em Celsius e informe a média delas. A leitura deve ser encerrada ao ser enviado o valor -273°C.

# %%
# Variáveis de controle
soma = 0
quantidade = 0

# Entrada de dados
temperatura = float(input("Digite a temperatura em °C (-273 para encerrar): "))

# Processamento
while temperatura != -273:

    soma += temperatura
    quantidade += 1

    temperatura = float(input("Digite a temperatura em °C (-273 para encerrar): "))

# Verifica se houve temperaturas válidas
if quantidade > 0:
    media = soma / quantidade
    print(f'\nA média das temperaturas é: {media:.2f}°C')
else:
    print("Nenhuma temperatura válida foi informada.")

# %% [markdown]
# 5) Escreva um programa que calcule o fatorial de um número inteiro fornecido pela pessoa usuária. Lembrando que o fatorial de um número inteiro é a multiplicação desse número por todos os seus antecessores até o número 1. Por exemplo, o fatorial de 5 é 5 x 4 x 3 x 2 x 1 = 120.

# %%
# Entrada do valor inteiro
numero = int(input("Digite um número inteiro: "))

# Processamento
fatorial = 1
for i in range(1, numero + 1):
    fatorial *= i

# Saída do resultado
print(f"O fatorial de {numero} é {fatorial}")
# Out:
# Digite um número inteiro: 5
# O fatorial de 5 é 120
